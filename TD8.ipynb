# %% [markdown]
# Imports de base

# %%
import pandas as pd

from Corpus import Corpus
from Document import Document
from SearchEngine import SearchEngine

# %% [markdown]
# Chargement du fichier

# %%
try:
    df = pd.read_csv("discours_US.csv", sep="\t", on_bad_lines="skip", engine='python')
except Exception as e:
    print(f"Error with tab delimiter: {e}")
    try:
        df = pd.read_csv("discours_US.csv", on_bad_lines="skip", engine='python')
    except Exception as e2:
        print(f"Error with comma delimiter: {e2}")
        df = pd.read_csv("discours_US.csv", sep="\t", on_bad_lines="skip", encoding='utf-8')

df.head()
# Out:
#    speaker                                               text  \
# 0  CLINTON  : I'm getting ready for a lot of things, a lot...
# 1  CLINTON  [ ] : I'll be graduating in May, and on gradua...
# 2  CLINTON  So, congratulations on this new poll number in...
# 3  CLINTON  Thank you, Madam Secretary. This is a big inte...
# 4  CLINTON  Wow! What a night. An unbelievable night. What...
#
#                date                                              descr  \
# 0    April 12, 2015   Video Remarks Announcing Candidacy for President
# 1    April 14, 2015  Remarks in a Question and Answer Session at Ki...
# 2  October 16, 2015                  Interview with Jake tapper of CNN
# 3   January 5, 2016             Interview with Chris Matthews of MSNBC
# 4  February 1, 2016    Remarks in Des Moines Following the Iowa Caucus
#
#                                                 link
# 0  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 1  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 2  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 3  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 4  http://www.presidency.ucsb.edu/ws/index.php?pi...

# %% [markdown]
# Distribution des auteurs (value_counts)

# %%
print("Available columns:", df.columns.tolist())
author_col = None
for col in ['author', 'Author', 'auteur', 'Auteur', 'speaker']:
    if col in df.columns:
        author_col = col
        break

if author_col:
    df[author_col].value_counts().head(20)
else:
    print(f"No author column found. Available columns: {df.columns.tolist()}")
# Out:
# Available columns: ['speaker', 'text', 'date', 'descr', 'link']

# %% [markdown]
# onstruction du Corpus à partir du DataFrame

# %%
corpus_discours = Corpus("DiscoursUS")

for _, row in df.iterrows():
    doc = Document(
        row.get("descr", "(Sans titre)"),
        row.get("speaker", "Inconnu"),
        row.get("date", ""),
        row.get("link", ""),
        row.get("text", ""),
    )
    corpus_discours.add_document(doc)

print(corpus_discours)
# Out:
# Corpus('DiscoursUS', ndoc=25, naut=2)

# %% [markdown]
# Test de la fonction search

# %%
corpus_discours.search("america")[:5]
# Out:
# ["ething, too. I'm running for president. Americans have fought their way back from tough",
#  ' in favor of those at the top. Everyday Americans need a champion and I want to be that',
#  "head, because when families are strong, America is strong. So I'm hitting the road to e",
#  "'m here today. I think we all know that Americans have come back from some tough econom",
#  'our country are much better off because American families have basically done whatever ']

# %% [markdown]
# Test de la fonction concorde

# %%
concorde = corpus_discours.concorde("freedom")
concorde[:10]
# Out:
#                             contexte_gauche motif_trouve  \
# 0  ent. This happens every time there is a       Freedom
# 1  r with reforms that give you choice and       freedom
# 2  very disadvantaged child in America the       freedom
# 3  ds will include religious and political       freedom
# 4  Here, in America, I will push to expand       freedom
# 5   betrayed our workers, our borders, our       freedom
# 6   so many lives were given in service to       freedom
# 7  iefs about equality and opportunity and       freedom
#
#                              contexte_droit
# 0   of Information Act request. If somethin
# 1   and control in healthcare – at a much l
# 2   to choose the private, public, magnet o
# 3   for the Cuban people. Let's also talk a
# 4   for all of our people. I am going to lo
# 5  s, and our sovereign rights as a nation.
# 6  . Amazing place. President Lincoln serve
# 7   and common decency. That's something to

# %% [markdown]
# Initialisation du moteur de recherche

# %%
engine = SearchEngine(corpus_discours)
engine
# Out:
# === Construction de l'index (TD7) ===
# - Nombre de documents : 25
# - Taille du vocabulaire : 5011
# === Index construit ===

# %% [markdown]
# Tests simples du moteur de recherche

# %%
import importlib, SearchEngine
importlib.reload(SearchEngine)
engine = SearchEngine.SearchEngine(corpus_discours)
engine.search("america security", 5)
# Out:
# === Construction de l'index (TD7) ===
# - Nombre de documents : 25
# - Taille du vocabulaire : 5011
# === Index construit ===
#    doc_id     score                                              titre  \
# 0      22  0.042310  Remarks at the Kent State Student Recreation C...
# 1      20  0.038462  Remarks on Proposals for the First 100 Days in...
# 2      12  0.036412  Remarks on Immigration at the Phoenix Conventi...
# 3      17  0.028300  Remarks at a Rally at the James L. Knight Cent...
# 4      11  0.024341  Remarks at the Charlotte Convention Center in ...
#
#     auteur                date     type  \
# 0  CLINTON    October 31, 2016  generic
# 1    TRUMP    October 22, 2016  generic
# 2    TRUMP     August 31, 2016  generic
# 3    TRUMP  September 16, 2016  generic
# 4    TRUMP     August 18, 2016  generic
#
#                                                  url
# 0  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 1  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 2  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 3  http://www.presidency.ucsb.edu/ws/index.php?pi...
# 4  http://www.presidency.ucsb.edu/ws/index.php?pi...

# %% [markdown]
# Préparation pour tqdm (barre de progression)

# %%
from tqdm.notebook import tqdm

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\andre\AppData\Local\Programs\Python\Python313\python.exe

# %%
import ipywidgets as widgets
print(widgets)
# Out:
# <module 'ipywidgets' from 'C:\\Users\\andre\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\ipywidgets\\__init__.py'>

# %%
import ipywidgets as widgets
from IPython.display import display

display(widgets.Button(description="Test"))
# Out:
# Button(description='Test', style=ButtonStyle())

# %%
import notebook
print(notebook.__version__)
# Out:
# 7.5.0

# %%
# !pip install -U jupyterlab_widgets ipywidgets
# Out:
# Requirement already satisfied: jupyterlab_widgets in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (3.0.16)
# Requirement already satisfied: ipywidgets in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (9.8.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\andre\appdata\local\programs\python\python313\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Imports pour l’interface graphique (widgets)

# %%
try:
    import ipywidgets as widgets
    from IPython.display import display, clear_output
except ImportError:
    widgets = None
    display = clear_output = None
    print("ipywidgets non disponible ? UI d?sactiv?e.")

# %% [markdown]
# Création des widgets de base

# %%
if widgets is None:
    print("Interface widgets d?sactiv?e (ipywidgets manquant).")
else:
    label_titre = widgets.Label("Moteur de recherche")
    
    input_query = widgets.Text(
        description="Mots clés :",
        placeholder="mot1 mot2 mot3"
    )
    
    slider_n = widgets.IntSlider(
        value=10,
        min=1,
        max=50,
        step=1,
        description="Nombre d'articles :"
    )
    
    button_search = widgets.Button(
        description="Rechercher",
        button_style="primary"
    )
    
    output_results = widgets.Output()

# %% [markdown]
# Mise en page de l’interface

# %%
from IPython.display import display
if widgets is None:
    print("Interface widgets d?sactiv?e (ipywidgets manquant).")
else:
    
    ligne_haut = widgets.HBox([input_query, slider_n, button_search])
    ui = widgets.VBox([label_titre, ligne_haut, output_results])
    
    display(ui)
# Out:
# VBox(children=(Label(value='Moteur de recherche'), HBox(children=(Text(value='', description='Mots clés :', pl…

# %% [markdown]
# Fonction clique_bouton (lance la recherche)

# %%
if widgets is None:
    print("Interface widgets d?sactiv?e (ipywidgets manquant).")
else:
    
    def clique_bouton(b):
        query = input_query.value.strip()
        n = slider_n.value
    
        with output_results:
            clear_output()
    
            if not query:
                print("⚠️ Veuillez entrer au moins un mot-clé.")
                return
    
            results = engine.search(query, n)
    
            if results.empty:
                print("Aucun document trouvé.")
            else:
                cols = ["doc_id", "score", "titre", "auteur"]
                display(results[cols])
    
    button_search.on_click(clique_bouton)

# %% [markdown]
# Ajout d’un filtre sur l’auteur

# %%
if widgets is None:
    print("Interface widgets d?sactiv?e (ipywidgets manquant).")
else:
    
    
    input_author = widgets.Text(
        description="Filtrer auteur :",
        placeholder="nom (facultatif)"
    )
    
    ligne_haut = widgets.HBox([input_query, slider_n, input_author, button_search])
    ui = widgets.VBox([label_titre, ligne_haut, output_results])
    
    display(ui)
    
    def clique_bouton_with_filter(b):
        query = input_query.value.strip()
        n = slider_n.value
        auteur_filtre = input_author.value.strip().lower()
    
        with output_results:
            clear_output()
    
            if not query:
                print("⚠️ Veuillez entrer au moins un mot-clé.")
                return
    
            results = engine.search(query, n)
    
            if auteur_filtre:
                results = results[results["auteur"].str.lower().str.contains(auteur_filtre)]
    
            if results.empty:
                print("Aucun document trouvé.")
            else:
                cols = ["doc_id", "score", "auteur", "titre"]
                display(results[cols])
    
    button_search.on_click(clique_bouton_with_filter)
# Out:
# VBox(children=(Label(value='Moteur de recherche'), HBox(children=(Text(value='', description='Mots clés :', pl…
